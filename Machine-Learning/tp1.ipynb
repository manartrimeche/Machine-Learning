# %%
import pandas as pd
df=pd.read_csv("/content/sample_data/Cancer_Dataset.csv")

# %%
df.head(10)
# Out:
#    PatientID first_name     last_name   BirthDate  gender  \
# 0        1.0     Marlee       Merrgen   7/29/2011   Homme
# 1        2.0    Heinrik        Baelde   9/25/1992    Male
# 2        3.0        NaN        Duffyn   5/10/1950   Homme
# 3        4.0    Ninette  Checchetelli   3/21/2007   Homme
# 4        5.0      Neala         Dible   7/10/2006   Femme
# 5        6.0      Prudy          Amer    9/2/2018       F
# 6        7.0        NaN        Castro   4/26/1969       H
# 7        8.0  Cassandre      Matveiko  11/18/1997       H
# 8        9.0    Nikolos     Charrette    6/7/2004    Male
# 9       10.0   Clarette       Couling  11/11/1945  Female
#
#                  Obesity Smoking Genetic Risk Cancer Prediction Level
# 0   Obésité de classe II     Yes          NaN                  Medium
# 1   Obésité de classe II      No          Yes                  Medium
# 2  Poids normal Surpoids     Yes        Maybe                     Low
# ...

# %%
df.tail()
# Out:
#      PatientID first_name last_name   BirthDate gender                Obesity  \
# 995      996.0       Luke   Mongeot    9/7/1937      H  Obésité de classe III
# 996      997.0       Fran  Stoggell    8/5/1943  Femme             Sous-poids
# 997      998.0       Jase     Paaso    6/8/1963      H  Poids normal Surpoids
# 998      999.0    Charlot    Woolis   9/13/1940  Femme    Obésité de classe I
# 999     1000.0    Sherrie     Skett  10/30/1984  Femme  Obésité de classe III
#
#     Smoking Genetic Risk Cancer Prediction Level
# 995      No          Yes                  Medium
# 996      No           No                    High
# 997     Yes          Yes                    High
# 998     Yes        Maybe                    High
# 999     Yes           No                     Low

# %%
df.sample()
# Out:
#      PatientID first_name last_name   BirthDate gender              Obesity  \
# 585      586.0      Ranna      Vann  11/15/2020      F  Obésité de classe I
#
#     Smoking Genetic Risk Cancer Prediction Level
# 585     Yes        Maybe                     Low

# %%
df.columns
# Out:
# Index(['PatientID', 'first_name', 'last_name', 'BirthDate', 'gender',
#        'Obesity', 'Smoking', 'Genetic Risk', 'Cancer Prediction Level'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PatientID                978 non-null    float64
#  1   first_name               969 non-null    object
#  2   last_name                1000 non-null   object
#  3   BirthDate                1000 non-null   object
#  4   gender                   980 non-null    object
#  5   Obesity                  1000 non-null   object
#  6   Smoking                  1000 non-null   object
#  7   Genetic Risk             962 non-null    object
#  8   Cancer Prediction Level  962 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#          PatientID
# count   978.000000
# mean    499.641104
# std     289.330383
# min       1.000000
# 25%     248.250000
# 50%     499.500000
# 75%     749.750000
# max    1000.000000

# %%
df.isnull()
# Out:
#      PatientID  first_name  last_name  BirthDate  gender  Obesity  Smoking  \
# 0        False       False      False      False   False    False    False
# 1        False       False      False      False   False    False    False
# 2        False        True      False      False   False    False    False
# 3        False       False      False      False   False    False    False
# 4        False       False      False      False   False    False    False
# ..         ...         ...        ...        ...     ...      ...      ...
# 995      False       False      False      False   False    False    False
# 996      False       False      False      False   False    False    False
# 997      False       False      False      False   False    False    False
# 998      False       False      False      False   False    False    False
# 999      False       False      False      False   False    False    False
#
#      Genetic Risk  Cancer Prediction Level
# ...

# %%
df.isnull().sum()
# Out:
# PatientID                  22
# first_name                 31
# last_name                   0
# BirthDate                   0
# gender                     20
# Obesity                     0
# Smoking                     0
# Genetic Risk               38
# Cancer Prediction Level    38
# dtype: int64

# %%
df.shape
# Out:
# (1000, 9)

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (859, 9)

# %%
df.drop_duplicates()
# Out:
#      PatientID first_name     last_name   BirthDate gender  \
# 1          2.0    Heinrik        Baelde   9/25/1992   Male
# 3          4.0    Ninette  Checchetelli   3/21/2007  Homme
# 4          5.0      Neala         Dible   7/10/2006  Femme
# 5          6.0      Prudy          Amer    9/2/2018      F
# 7          8.0  Cassandre      Matveiko  11/18/1997      H
# ..         ...        ...           ...         ...    ...
# 995      996.0       Luke       Mongeot    9/7/1937      H
# 996      997.0       Fran      Stoggell    8/5/1943  Femme
# 997      998.0       Jase         Paaso    6/8/1963      H
# 998      999.0    Charlot        Woolis   9/13/1940  Femme
# 999     1000.0    Sherrie         Skett  10/30/1984  Femme
#
#                    Obesity Smoking Genetic Risk Cancer Prediction Level
# 1     Obésité de classe II      No          Yes                  Medium
# 3      Obésité de classe I     Yes           No                     Low
# ...

# %%
df.shape
# Out:
# (859, 9)

# %%
df['full_name']=df['first_name']+''+df['last_name']

# %%
df.sample()
# Out:
#      PatientID first_name  last_name  BirthDate gender              Obesity  \
# 789      790.0      Ashly  Antonucci  2/20/1963      H  Obésité de classe I
#
#     Smoking Genetic Risk Cancer Prediction Level       full_name
# 789     Yes        Maybe                  Medium  AshlyAntonucci

# %%
df.head()
# Out:
#    PatientID first_name     last_name   BirthDate gender  \
# 1        2.0    Heinrik        Baelde   9/25/1992   Male
# 3        4.0    Ninette  Checchetelli   3/21/2007  Homme
# 4        5.0      Neala         Dible   7/10/2006  Femme
# 5        6.0      Prudy          Amer    9/2/2018      F
# 7        8.0  Cassandre      Matveiko  11/18/1997      H
#
#                  Obesity Smoking Genetic Risk Cancer Prediction Level  \
# 1   Obésité de classe II      No          Yes                  Medium
# 3    Obésité de classe I     Yes           No                     Low
# 4         Obesité exteme      No        Maybe                  Medium
# 5  Obésité de classe III      No          Yes                     Low
# 7  Poids normal Surpoids      No        Maybe                     Low
#
#              full_name
# 1        HeinrikBaelde
# 3  NinetteChecchetelli
# 4           NealaDible
# 5            PrudyAmer
# 7    CassandreMatveiko

# %%
df=df.drop(columns=['PatientID','full_name','last_name','first_name'])

# %%
df.shape
# Out:
# (859, 6)

# %%
df.columns
# Out:
# Index(['BirthDate', 'gender', 'Obesity', 'Smoking', 'Genetic Risk',
#        'Cancer Prediction Level'],
#       dtype='object')

# %%
df['BirthDate']=pd.to_datetime(df['BirthDate'])

# %%
df['Age']=pd.to_datetime('today').year-df['BirthDate'].dt.year

# %%
df['Age']=df['Age'].astype(int)

# %%
df.sample(
)
# Out:
#      BirthDate gender                Obesity Smoking Genetic Risk  \
# 330 1986-10-11   Male  Poids normal Surpoids      No           No
#
#     Cancer Prediction Level  Age
# 330                     Low   39

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Homme', 'Femme', 'F', 'H', 'Female'], dtype=object)

# %%
df['gender']=df['gender'].replace({'F':1,'Femme':1,'Female':1,'H':0,'Homme':0,'Male':0})
# Out:
# <ipython-input-133-8ade84f0a520>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['gender']=df['gender'].replace({'F':1,'Femme':1,'Female':1,'H':0,'Homme':0,'Male':0})

# %%
df['gender'].unique()
# Out:
# array([0, 1])

# %%
df['Obesity'].unique()
# Out:
# array(['Obésité de classe II', 'Obésité de classe I', 'Obesité exteme',
#        'Obésité de classe III', 'Poids normal Surpoids', 'Sous-poids'],
#       dtype=object)

# %%
df['Obesity']=df['Obesity'].replace({'Sous-poids':-1,'Poids normal Surpoids':0,'Obésité de classe I':1,'Obésité de classe II':2,'Obésité de classe III':3,'Obesité exteme':4,})
# Out:
# <ipython-input-136-23f2f9ec2761>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Obesity']=df['Obesity'].replace({'Sous-poids':-1,'Poids normal Surpoids':0,'Obésité de classe I':1,'Obésité de classe II':2,'Obésité de classe III':3,'Obesité exteme':4,})

# %%
df['Obesity'].unique()
# Out:
# array([ 2,  1,  4,  3,  0, -1])

# %%
df['Cancer Prediction Level'].unique()
# Out:
# array(['Medium', 'Low', 'High'], dtype=object)

# %%
df['Cancer Prediction Level']=df['Cancer Prediction Level'].replace({'Low':1,'Medium':2,'High':3})
# Out:
# <ipython-input-139-2e807835ed6e>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Cancer Prediction Level']=df['Cancer Prediction Level'].replace({'Low':1,'Medium':2,'High':3})

# %%
df['Cancer Prediction Level'].unique()
# Out:
# array([2, 1, 3])

# %%
df['Genetic Risk'].unique()
# Out:
# array(['Yes', 'No', 'Maybe'], dtype=object)

# %%
df['Genetic Risk']=df['Genetic Risk'].replace({'Yes':1,'Maybe':2,'No':3})
# Out:
# <ipython-input-142-6e179b180a60>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Genetic Risk']=df['Genetic Risk'].replace({'Yes':1,'Maybe':2,'No':3})

# %%
df['Genetic Risk'].unique()
# Out:
# array([1, 3, 2])

# %%
df.head()
# Out:
#    BirthDate  gender  Obesity Smoking  Genetic Risk  Cancer Prediction Level  \
# 1 1992-09-25       0        2      No             1                        2
# 3 2007-03-21       0        1     Yes             3                        1
# 4 2006-07-10       1        4      No             2                        2
# 5 2018-09-02       1        3      No             1                        1
# 7 1997-11-18       0        0      No             2                        1
#
#    Age
# 1   33
# 3   18
# 4   19
# 5    7
# 7   28

# %%
ages=[0,18,30,40,50,60,70,float('inf')]

# %%
groups=['0-18','19-30','31-40','41-50','51-60','61-70','71+']

# %%
df['AgeGroup']=pd.cut(df['Age'],bins=ages,labels=groups,right=False)
print(df['AgeGroup'])
# Out:
# 1      31-40
# 3      19-30
# 4      19-30
# 5       0-18
# 7      19-30
#        ...
# 995      71+
# 996      71+
# 997    61-70
# 998      71+
# 999    41-50
# Name: AgeGroup, Length: 859, dtype: category
# Categories (7, object): ['0-18' < '19-30' < '31-40' < '41-50' < '51-60' < '61-70' < '71+']

# %%
df=df.drop(columns=['Age'])

# %%
df.head()
# Out:
#    BirthDate  gender  Obesity Smoking  Genetic Risk  Cancer Prediction Level  \
# 1 1992-09-25       0        2      No             1                        2
# 3 2007-03-21       0        1     Yes             3                        1
# 4 2006-07-10       1        4      No             2                        2
# 5 2018-09-02       1        3      No             1                        1
# 7 1997-11-18       0        0      No             2                        1
#
#   AgeGroup
# 1    31-40
# 3    19-30
# 4    19-30
# 5     0-18
# 7    19-30

# %%
grouped=df.groupby(['Cancer Prediction Level','AgeGroup']).size()
print(grouped)
# Out:
# <ipython-input-150-1c3f5df1a23b>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped=df.groupby(['Cancer Prediction Level','AgeGroup']).size()
# Cancer Prediction Level  AgeGroup
# 1                        0-18        43
#                          19-30       50
#                          31-40       28
#                          41-50       37
#                          51-60       33
#                          61-70       23
#                          71+         89
# 2                        0-18        48
#                          19-30       40
#                          31-40       31
#                          41-50       29
#                          51-60       31
#                          61-70       27
#                          71+         68
# ...

# %%
df['Cancer Prediction Level'].unique()
# Out:
# array([2, 1, 3])

# %%
plt.figure(figsize=(4,3))
sns.countplot(x='Cancer Prediction Level',data=df)
plt.xlabel)
