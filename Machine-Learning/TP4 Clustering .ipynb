# %%
# !pip install kaggle

# %%
import pandas as pd

# %%
df = pd.read_csv('Mall_Customers.csv')

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-4fe186e0130b> in <cell line: 0>()
# ----> 1 df = pd.read_csv('Mall_Customers.csv')
#       2
#       3 df.head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.info()

# %%
df.describe()

# %%
# prompt: Il y a-t-il des attributs à supprimer de ce lot de données ?

# Check for columns with a high percentage of missing values
missing_percentage = df.isnull().sum() * 100 / len(df)
columns_to_drop = missing_percentage[missing_percentage > 50].index.tolist()  # Adjust the threshold (50%) as needed
print(f"Columns with more than 50% missing values: {columns_to_drop}")

# Check for duplicate rows and consider dropping them
duplicate_rows = df.duplicated()
print(f"Number of duplicate rows: {duplicate_rows.sum()}")
# If there are duplicates and you want to remove them:
# df.drop_duplicates(inplace=True)

# Check for columns with low variance that might not be informative.
# Calculate variance for numerical columns
numerical_cols = df.select_dtypes(include=['number'])
low_variance_cols = numerical_cols.columns[numerical_cols.var() < 0.1] # Set a variance threshold
print(f"Columns with low variance: {low_variance_cols.tolist()}")

# Example: Dropping columns (replace with your identified columns)
# columns_to_remove = ['CustomerID'] # Example: CustomerID might not be predictive
# if columns_to_remove:
#    df.drop(columns=columns_to_remove, inplace=True)
#    print(f"Removed columns: {columns_to_remove}")

# Display the updated DataFrame info
df.info()

# %%
# prompt: Visualisezla répartition des clients selon l'âge, le revenu annuel et le score de dépenses.

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Assuming 'Age', 'Annual Income (k$)', and 'Spending Score (1-100)' are your columns
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

x = df['Age']
y = df['Annual Income (k$)']
z = df['Spending Score (1-100)']

ax.scatter(x, y, z, c=z, marker='o')  # Use z for color mapping

ax.set_xlabel('Age')
ax.set_ylabel('Annual Income (k$)')
ax.set_zlabel('Spending Score (1-100)')
ax.set_title('3D Scatter Plot of Customer Segmentation')

plt.show()

# %%
# prompt: Utifiser l’encodage one-hot pour convertir le contenu de la variable catégorique "Gender".
# NB: Cette opération d'encodage one-hot transforme une variable catégorique comme 'Gender' en
# plusieurscolonnes binaires (0 ou 1), une pour chaque catégorie possible dans la colonne 'Gender'. Par
# exemple, si 'Gender' contient les valeurs 'Male' et 'Female', après l'encodage, vous aurez deux
# nouvelles colonnes: 'Gender_Male' et 'Gender_Female'.
# Si un individu est masculin, la colonne 'Gender_Male'aura la valeur 1 et 'Gender_Female' sera
# à 0, et vice versa pour une personne féminine.

# Perform one-hot encoding on the 'Gender' column
data = pd.get_dummies(data, columns=['Gender'], drop_first=True)

# Display the updated DataFrame to see the new columns
print(df.head())
